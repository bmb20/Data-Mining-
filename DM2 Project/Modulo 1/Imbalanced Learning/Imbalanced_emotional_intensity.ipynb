# %% [markdown]
# - Define one simple unbalanced classification tasks and solve it with Decision Tree or KNN.
# - If the dataset is already unbalanced leave it as it is, otherwise turns the dataset into an imbalanced version (e.g., 96% - 4%, for binary classification).
# - Then solve the classification task using the Decision Tree or KNN by adopting at least 2 techniques of imbalanced learning (Undersampling, Oversampling).

# %%
from sklearn.model_selection import train_test_split, cross_val_score 

from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import scale
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler

from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.metrics import roc_curve, auc, roc_auc_score

# %%
df_test = pd.read_csv("/content/Test_ripulito")
df_train = pd.read_csv("/content/Train_ripulito")

# %%
df_test = df_test.drop(columns=['Unnamed: 0'])
df_train = df_train.drop(columns=['Unnamed: 0'])

# %%
df_train_copy = df_train
df_test_copy = df_test

# %%
t_train = df_train.drop(columns=['vocal_channel', 'emotion', 'emotional_intensity', 'statement', 'repetition', 'sex', 'filename'])

# %%
t_test = df_test.drop(columns=['vocal_channel', 'emotion', 'emotional_intensity', 'statement', 'repetition', 'sex', 'filename'])

# %%
columns_train = []
columns_train = t_train.columns

# %%
columns_test = []
columns_test = t_test.columns

# %%
columns_train
# Out:
# Index(['sum', 'std', 'q25', 'q50', 'q75', 'kur', 'skew', 'lag1_sum',
#        'lag1_q25', 'lag1_q50',
#        ...
#        'sc_max_w4', 'sc_q25_w4', 'sc_kur_w4', 'sc_skew_w4', 'stft_sum_w4',
#        'stft_mean_w4', 'stft_std_w4', 'stft_min_w4', 'stft_kur_w4',
#        'stft_skew_w4'],
#       dtype='object', length=242)

# %%
scaler = StandardScaler()
x_train_norm = scaler.fit_transform(t_train)
#print(x_train_norm)
x_test_norm = scaler.transform(t_test)
#print(x_test_norm)

# %%
df_trainNORM = pd.DataFrame(x_train_norm, columns = columns_train)
df_testNORM = pd.DataFrame(x_test_norm, columns = columns_test)

# %%
"""df_trainNORM = df_trainNORM.assign(vocal_channel = df_train_copy['vocal_channel'].values)
df_trainNORM = df_trainNORM.assign(emotion = df_train_copy['emotion'].values)
df_trainNORM = df_trainNORM.assign(statement = df_train_copy['statement'].values)
df_trainNORM = df_trainNORM.assign(repetition = df_train_copy['repetition'].values)
df_trainNORM = df_trainNORM.assign(sex = df_train_copy['sex'].values)
df_trainNORM = df_trainNORM.assign(filename = df_train_copy['filename'].values)"""
df_trainNORM = df_trainNORM.assign(emotional_intensity = df_train_copy['emotional_intensity'].values)

# %%
#df_trainNORM

# %%
"""df_testNORM = df_testNORM.assign(vocal_channel = df_test_copy['vocal_channel'].values)
df_testNORM = df_testNORM.assign(emotion = df_test_copy['emotion'].values)
df_testNORM = df_testNORM.assign(statement = df_test_copy['statement'].values)
df_testNORM = df_testNORM.assign(repetition = df_test_copy['repetition'].values)
df_testNORM = df_testNORM.assign(sex = df_test_copy['sex'].values)
df_testNORM = df_testNORM.assign(filename = df_test_copy['filename'].values)"""
df_testNORM = df_testNORM.assign(emotional_intensity = df_test_copy['emotional_intensity'].values)

# %%
#df_testNORM

# %% [markdown]
# sbilanciamento emotional_intensity sul train set

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df_trainNORM['emotional_intensity']= label_encoder.fit_transform(df_trainNORM['emotional_intensity']) 
df_testNORM['emotional_intensity'] = label_encoder.transform(df_testNORM['emotional_intensity'])

# %%
#classe da sbilanciare
class_name = 'emotional_intensity'

# %%
#sbilanciamento train
attributes = [col for col in df_trainNORM.columns if col != class_name]
X = df_trainNORM[attributes].values
y = df_trainNORM[class_name]

# %%
ax = sns.countplot(y="emotional_intensity", data=df_trainNORM)
plt.title('Distribution of emotional intensity')
plt.xlabel('Number of records')
total = len(df_trainNORM['emotional_intensity'])
for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_width()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))

plt.show()

# %%
df_trainNORM['emotional_intensity'].value_counts() 
#0 = normal
#1 = strong
# Out:
# 0    984
# 1    844
# Name: emotional_intensity, dtype: int64

# %%
from imblearn.datasets import make_imbalance
seed = 100
attributes = [col for col in df_trainNORM.columns if col != class_name]
X = df_trainNORM[attributes]
y = df_trainNORM[class_name]
#sbilanciamento 96% e 4%
X_res, y_res = make_imbalance(X, y, sampling_strategy={0: 984, 1: 41}, random_state=seed)

dxres = pd.DataFrame(X_res)
dyres = pd.DataFrame(y_res)

df2_train_sbil=pd.concat([dxres, dyres], axis=1, join="inner")
#attr= [col for col in df_trainNORM.columns]
#df2.columns = attr
ax = sns.countplot(y="emotional_intensity", data=df2_train_sbil)
plt.title('Distribution of emotional intensity')
plt.xlabel('Number of records')
total = len(df2_train_sbil['emotional_intensity'])
for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_width()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))

plt.show()

# %%
#df2_train

# %% [markdown]
# sbilanciamento emotional_intensity sul Test Set

# %%
#sbilanciamento test
attributes2 = [col for col in df_testNORM.columns if col != class_name]
X = df_testNORM[attributes2].values
y = df_testNORM[class_name]

# %%
ax = sns.countplot(y="emotional_intensity", data=df_testNORM)
plt.title('Distribution of emotional intensity')
plt.xlabel('Number of records')
total = len(df_testNORM['emotional_intensity'])
for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_width()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))

plt.show()

# %%
df_testNORM['emotional_intensity'].value_counts()
# Out:
# 0    336
# 1    288
# Name: emotional_intensity, dtype: int64

# %%
from imblearn.datasets import make_imbalance
seed = 100
attributes = [col for col in df_testNORM.columns if col != class_name]
X = df_testNORM[attributes]
y = df_testNORM[class_name]
#sbilanciamento 96% e 4%
X_res, y_res = make_imbalance(X, y, sampling_strategy={0: 336, 1: 14}, random_state=seed)

dxres = pd.DataFrame(X_res)
dyres = pd.DataFrame(y_res)

df2_test_sbil=pd.concat([dxres, dyres], axis=1, join="inner")
#attr= [col for col in df_trainNORM.columns]
#df2.columns = attr
ax = sns.countplot(y="emotional_intensity", data=df2_test_sbil)
plt.title('Distribution of emotional intensity')
plt.xlabel('Number of records')
total = len(df2_test_sbil['emotional_intensity'])
for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_width()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))

plt.show()

# %%
#df2_test_sbil

# %%
#!pip install scikit-plot
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split, cross_val_score 
from scikitplot.metrics import plot_precision_recall, plot_roc, plot_cumulative_gain, plot_lift_curve
from sklearn.metrics import roc_curve, auc, roc_auc_score
from scikitplot.metrics import plot_roc_curve
from sklearn.model_selection import KFold, StratifiedKFold,RepeatedStratifiedKFold, cross_val_score, KFold, RandomizedSearchCV,GridSearchCV, RepeatedKFold
from sklearn import tree
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, f1_score, classification_report

# %%
X_train = df2_train_sbil.drop(columns = ['emotional_intensity'])
y_train = df2_train_sbil[['emotional_intensity']]
X_test = df2_test_sbil.drop(columns = ['emotional_intensity'])
y_test = df2_test_sbil[['emotional_intensity']]

# %%
# Funzione per fare la GridSearch()

def customGridSearch(X_train, y_train, model, tuned_parameters,score):

    print("____________________________________________ START GRID SEARCH ____________________________________________")

    results = {}
    
    print("------- Score = " + score +  "------- \n")
        
    k_fold = RepeatedStratifiedKFold() # 5 split default, 10 repetitions default
    print("> Fold = " + str(k_fold) + "\n")
        
    clf = GridSearchCV(model, tuned_parameters, error_score='raise', cv=k_fold, scoring = score, return_train_score=True)
    clf.fit(X_train, y_train)

    print("> Best Parameter set: \n")
    best = clf.best_params_
    print(best)
        
    print("\n> Grid scores:\n")

    means = clf.cv_results_['mean_train_score']
    stds = clf.cv_results_['std_train_score']

    print("...........RESULTS FOR TRAINING.........")
    print("........................................")

   
    
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
                          
    print("____________________________________________ END GRID SEARCH ____________________________________________")
        
    results[score] = best
    
    return results

# %% [markdown]
# Prove con sbilanciamento su dataset normalizzati

# %%
from sklearn.dummy import DummyClassifier

# %%
clf = DummyClassifier()
clf.fit(X_train, y_train)

y_pred0 = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred0))
print('F1-score %s' % f1_score(y_test, y_pred0, average=None))
print(classification_report(y_test, y_pred0))
# Out:
# Accuracy 0.96
# F1-score [0.97959184 0.        ]
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       336
#            1       0.00      0.00      0.00        14
#
#     accuracy                           0.96       350
#    macro avg       0.48      0.50      0.49       350
# weighted avg       0.92      0.96      0.94       350
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_score = clf.predict_proba(X_test)
plot_roc(y_test, y_score)
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
"""check_params ={"criterion":["gini", "entropy"],
         "max_depth":[4, 6, 8, 10],
         "min_samples_split": [5, 10, 15, 20],
         "min_samples_leaf": [3, 5, 7, 9, 11]}

dt=DecisionTreeClassifier()
          
results = customGridSearch(X_train, y_train, dt, check_params, "f1_macro")"""
# Out:
# ____________________________________________ START GRID SEARCH ____________________________________________
# ------- Score = f1_macro-------
#
# > Fold = RepeatedStratifiedKFold(n_repeats=10, n_splits=5, random_state=None)
#
# > Best Parameter set:
#
# {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 5}
#
# > Grid scores:
#
# ...........RESULTS FOR TRAINING.........
# ........................................
# 0.750 (+/-0.058) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.716 (+/-0.095) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.689 (+/-0.101) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.661 (+/-0.116) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.692 (+/-0.102) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.696 (+/-0.102) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.662 (+/-0.099) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.619 (+/-0.129) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.662 (+/-0.121) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.660 (+/-0.132) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.656 (+/-0.140) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.586 (+/-0.179) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.601 (+/-0.169) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.598 (+/-0.171) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.601 (+/-0.169) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.587 (+/-0.166) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.574 (+/-0.165) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.574 (+/-0.165) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.574 (+/-0.165) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.576 (+/-0.170) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.802 (+/-0.071) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.741 (+/-0.100) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.704 (+/-0.105) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.671 (+/-0.128) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.732 (+/-0.095) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.732 (+/-0.101) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.689 (+/-0.096) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.633 (+/-0.158) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.691 (+/-0.119) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.686 (+/-0.132) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.687 (+/-0.130) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.604 (+/-0.173) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.609 (+/-0.191) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.611 (+/-0.186) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.612 (+/-0.188) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.597 (+/-0.175) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.577 (+/-0.166) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.582 (+/-0.169) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.580 (+/-0.164) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.577 (+/-0.166) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.845 (+/-0.060) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.767 (+/-0.096) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.730 (+/-0.101) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.686 (+/-0.141) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.755 (+/-0.104) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.759 (+/-0.099) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.713 (+/-0.105) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.641 (+/-0.157) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.696 (+/-0.110) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.689 (+/-0.125) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.690 (+/-0.123) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.614 (+/-0.160) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.608 (+/-0.189) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.608 (+/-0.189) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.609 (+/-0.191) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.597 (+/-0.175) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.579 (+/-0.170) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.582 (+/-0.169) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.579 (+/-0.170) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.582 (+/-0.169) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.865 (+/-0.063) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.787 (+/-0.091) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.747 (+/-0.109) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.699 (+/-0.150) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.770 (+/-0.085) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.769 (+/-0.084) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.722 (+/-0.102) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.656 (+/-0.152) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.696 (+/-0.108) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.691 (+/-0.133) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.688 (+/-0.128) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.617 (+/-0.152) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.611 (+/-0.186) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.611 (+/-0.186) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.611 (+/-0.186) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.600 (+/-0.172) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.580 (+/-0.164) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.577 (+/-0.166) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.580 (+/-0.164) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.582 (+/-0.169) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.813 (+/-0.096) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.788 (+/-0.112) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.772 (+/-0.114) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.741 (+/-0.174) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.775 (+/-0.110) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.776 (+/-0.112) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.759 (+/-0.122) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.724 (+/-0.184) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.749 (+/-0.120) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.750 (+/-0.121) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.746 (+/-0.115) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.711 (+/-0.181) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.708 (+/-0.174) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.705 (+/-0.173) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.706 (+/-0.172) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.704 (+/-0.170) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.692 (+/-0.164) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.692 (+/-0.164) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.690 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.691 (+/-0.164) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.891 (+/-0.089) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.858 (+/-0.097) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.830 (+/-0.119) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.786 (+/-0.169) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.838 (+/-0.101) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.839 (+/-0.099) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.813 (+/-0.114) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.768 (+/-0.146) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.807 (+/-0.111) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.805 (+/-0.111) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.797 (+/-0.121) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.750 (+/-0.143) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.749 (+/-0.140) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.748 (+/-0.138) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.747 (+/-0.138) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.738 (+/-0.135) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.717 (+/-0.146) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.717 (+/-0.146) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.715 (+/-0.144) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.717 (+/-0.146) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.927 (+/-0.067) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.884 (+/-0.088) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.854 (+/-0.097) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.804 (+/-0.143) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.867 (+/-0.085) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.867 (+/-0.087) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.837 (+/-0.092) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.785 (+/-0.141) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.828 (+/-0.091) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.826 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.817 (+/-0.106) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.763 (+/-0.130) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.764 (+/-0.132) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.761 (+/-0.131) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.763 (+/-0.135) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.745 (+/-0.130) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.724 (+/-0.136) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.725 (+/-0.137) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.725 (+/-0.137) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.726 (+/-0.137) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.943 (+/-0.043) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.900 (+/-0.067) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.861 (+/-0.077) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.811 (+/-0.124) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.879 (+/-0.066) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.882 (+/-0.064) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.845 (+/-0.080) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.789 (+/-0.123) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.835 (+/-0.081) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.835 (+/-0.081) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.824 (+/-0.093) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.763 (+/-0.139) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.766 (+/-0.132) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.763 (+/-0.131) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.767 (+/-0.133) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.752 (+/-0.129) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.726 (+/-0.137) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.726 (+/-0.138) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.725 (+/-0.136) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.727 (+/-0.137) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 20}
# ____________________________________________ END GRID SEARCH ____________________________________________

# %%
#results
# Out:
# {'f1_macro': {'criterion': 'entropy',
#   'max_depth': 6,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5}}

# %%
clf = DecisionTreeClassifier(criterion = 'entropy', max_depth = 6, min_samples_split=5, min_samples_leaf=5, random_state=42)
clf.fit(X_train, y_train)

y_pred0 = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred0))
print('F1-score %s' % f1_score(y_test, y_pred0, average=None))
print(classification_report(y_test, y_pred0))
# Out:
# Accuracy 0.9114285714285715
# F1-score [0.95267176 0.31111111]
#               precision    recall  f1-score   support
#
#            0       0.98      0.93      0.95       336
#            1       0.23      0.50      0.31        14
#
#     accuracy                           0.91       350
#    macro avg       0.60      0.71      0.63       350
# weighted avg       0.95      0.91      0.93       350

# %%
#ROC CURVE
y_score = clf.predict_proba(X_test)
fpr0, tpr0, _ = roc_curve(y_test, y_score[:, 1])
roc_auc0 = auc(fpr0, tpr0)

# %%
plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
#roc curve con decision tree allenato sui dati non bilanciati

# %%
y_score = clf.predict_proba(X_test)
plot_roc(y_test, y_score)
plt.show()

# %%
#DECISION TREE
clf = DecisionTreeClassifier(criterion = 'entropy', max_depth = 6, min_samples_split=5, min_samples_leaf=5, random_state=42)
clf.fit(X_train, y_train)

def adjusted_predict(X, thr=0.5):
    y_score = clf.predict_proba(X_test)[:, 1]
    return np.array([1 if y > thr else 0 for y in y_score])

y_pred = adjusted_predict(X_test, thr=0.9)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, thr = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# Accuracy 0.9285714285714286
# F1-score [0.96274218 0.13793103]
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96       336
#            1       0.13      0.14      0.14        14
#
#     accuracy                           0.93       350
#    macro avg       0.55      0.55      0.55       350
# weighted avg       0.93      0.93      0.93       350

# %%
#PCA
from sklearn.decomposition import PCA

# %%
X_train.shape
# Out:
# (1025, 242)

# %%
pca = PCA(n_components=2)
pca.fit(X_train)
X_pca = pca.transform(X_train)

# %%
X_pca.shape
# Out:
# (1025, 2)

# %%
np.unique(y_train, return_counts=True), np.unique(y_test, return_counts=True)
# Out:
# ((array([0, 1]), array([984,  41])), (array([0, 1]), array([336,  14])))

# %%
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_train['emotional_intensity'], cmap=plt.cm.prism, edgecolor='k', alpha=0.7)
plt.show()

# %% [markdown]
# UNDERSAMPLING

# %%
from imblearn.under_sampling import RandomUnderSampler
from imblearn.under_sampling import CondensedNearestNeighbour
from imblearn.under_sampling import TomekLinks
from imblearn.under_sampling import EditedNearestNeighbours
from collections import Counter
from collections import defaultdict

# %% [markdown]
# RandomUnderSampler

# %%
rus = RandomUnderSampler(random_state=42)
X_res, y_res = rus.fit_resample(X_train, y_train['emotional_intensity'])
print('Resampled dataset shape %s' % Counter(y_res))
# Out:
# Resampled dataset shape Counter({0: 41, 1: 41})

# %%
pca = PCA(n_components=2)
pca.fit(X_train)
X_pca = pca.transform(X_res)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_res, cmap=plt.cm.prism, edgecolor='k', alpha=0.7)
plt.show()

# %%
"""check_params ={"criterion":["gini", "entropy"],
         "max_depth":[4, 6, 8, 10],
         "min_samples_split": [5, 10, 15, 20],
         "min_samples_leaf": [3, 5, 7, 9, 11]}

dt=DecisionTreeClassifier()
          
results = customGridSearch(X_res, y_res, dt, check_params, "f1_macro")"""
# Out:
# ____________________________________________ START GRID SEARCH ____________________________________________
# ------- Score = f1_macro-------
#
# > Fold = RepeatedStratifiedKFold(n_repeats=10, n_splits=5, random_state=None)
#
# > Best Parameter set:
#
# {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 5}
#
# > Grid scores:
#
# ...........RESULTS FOR TRAINING.........
# ........................................
# 0.934 (+/-0.039) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.922 (+/-0.045) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.900 (+/-0.061) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.890 (+/-0.062) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.889 (+/-0.048) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.889 (+/-0.046) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.873 (+/-0.056) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.866 (+/-0.056) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.854 (+/-0.058) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.855 (+/-0.059) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.852 (+/-0.062) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.847 (+/-0.063) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.843 (+/-0.064) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.841 (+/-0.061) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.840 (+/-0.063) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.839 (+/-0.062) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.820 (+/-0.059) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.821 (+/-0.058) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.820 (+/-0.058) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.822 (+/-0.059) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.943 (+/-0.031) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.926 (+/-0.043) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.903 (+/-0.065) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.889 (+/-0.061) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.890 (+/-0.050) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.894 (+/-0.049) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.874 (+/-0.055) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.865 (+/-0.058) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.856 (+/-0.061) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.856 (+/-0.062) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.853 (+/-0.062) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.848 (+/-0.064) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.841 (+/-0.062) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.843 (+/-0.065) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.842 (+/-0.064) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.839 (+/-0.063) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.821 (+/-0.059) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.821 (+/-0.060) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.821 (+/-0.059) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.821 (+/-0.060) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.945 (+/-0.033) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.928 (+/-0.042) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.902 (+/-0.061) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.886 (+/-0.066) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.891 (+/-0.050) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.892 (+/-0.050) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.875 (+/-0.058) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.866 (+/-0.056) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.858 (+/-0.063) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.857 (+/-0.061) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.853 (+/-0.063) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.848 (+/-0.064) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.841 (+/-0.061) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.840 (+/-0.062) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.843 (+/-0.063) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.840 (+/-0.063) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.821 (+/-0.059) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.821 (+/-0.058) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.821 (+/-0.058) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.822 (+/-0.058) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.946 (+/-0.034) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.925 (+/-0.043) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.903 (+/-0.064) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.891 (+/-0.063) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.894 (+/-0.049) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.894 (+/-0.050) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.875 (+/-0.057) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.865 (+/-0.055) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.859 (+/-0.065) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.858 (+/-0.064) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.854 (+/-0.066) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.847 (+/-0.065) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.842 (+/-0.064) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.840 (+/-0.063) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.841 (+/-0.062) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.838 (+/-0.062) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.821 (+/-0.058) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.820 (+/-0.059) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.821 (+/-0.058) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.822 (+/-0.060) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.926 (+/-0.066) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.915 (+/-0.063) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.905 (+/-0.067) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.892 (+/-0.073) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.897 (+/-0.060) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.897 (+/-0.060) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.888 (+/-0.069) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.877 (+/-0.076) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.874 (+/-0.069) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.875 (+/-0.068) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.873 (+/-0.071) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.866 (+/-0.075) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.861 (+/-0.074) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.865 (+/-0.070) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.862 (+/-0.072) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.860 (+/-0.075) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.846 (+/-0.067) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.843 (+/-0.065) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.844 (+/-0.068) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.845 (+/-0.068) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.959 (+/-0.031) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.937 (+/-0.049) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.918 (+/-0.061) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.896 (+/-0.071) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.918 (+/-0.044) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.916 (+/-0.045) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.900 (+/-0.066) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.883 (+/-0.071) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.888 (+/-0.063) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.889 (+/-0.066) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.883 (+/-0.070) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.867 (+/-0.074) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.862 (+/-0.073) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.865 (+/-0.073) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.863 (+/-0.075) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.861 (+/-0.075) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.845 (+/-0.069) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.847 (+/-0.070) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.845 (+/-0.066) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.846 (+/-0.067) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.960 (+/-0.029) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.937 (+/-0.048) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.916 (+/-0.062) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.894 (+/-0.074) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.917 (+/-0.044) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.916 (+/-0.049) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.900 (+/-0.065) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.885 (+/-0.071) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.891 (+/-0.066) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.890 (+/-0.063) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.883 (+/-0.070) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.866 (+/-0.073) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.866 (+/-0.070) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.865 (+/-0.074) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.864 (+/-0.073) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.864 (+/-0.075) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.845 (+/-0.072) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.846 (+/-0.067) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.846 (+/-0.072) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.844 (+/-0.069) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.959 (+/-0.031) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.936 (+/-0.047) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.918 (+/-0.060) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.895 (+/-0.073) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.918 (+/-0.044) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.919 (+/-0.044) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.904 (+/-0.062) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.882 (+/-0.071) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.889 (+/-0.064) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.889 (+/-0.064) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.882 (+/-0.071) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.868 (+/-0.072) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.864 (+/-0.074) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.865 (+/-0.070) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.866 (+/-0.072) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.861 (+/-0.075) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.844 (+/-0.067) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.845 (+/-0.072) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.846 (+/-0.068) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.844 (+/-0.068) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 20}
# ____________________________________________ END GRID SEARCH ____________________________________________

# %%
#results
# Out:
# {'f1_macro': {'criterion': 'gini',
#   'max_depth': 6,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5}}

# %%
#DECISION TREE
clf = DecisionTreeClassifier(criterion =  'gini', max_depth = 6, min_samples_leaf = 5, min_samples_split = 5, random_state=42)
clf.fit(X_res, y_res)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# Accuracy 0.5942857142857143
# F1-score [0.73605948 0.12345679]
#               precision    recall  f1-score   support
#
#            0       0.98      0.59      0.74       336
#            1       0.07      0.71      0.12        14
#
#     accuracy                           0.59       350
#    macro avg       0.52      0.65      0.43       350
# weighted avg       0.94      0.59      0.71       350

# %%
"""check_params = {'n_neighbors': [1, 5, 10, 15, 20], "weights":["distance", "uniform"], 'metric' :['minkowski', 'manhattan', 'euclidean']}

clf=KNeighborsClassifier()
          
results = customGridSearch(X_res, y_res, clf, check_params, "f1_macro")"""
# Out:
# ____________________________________________ START GRID SEARCH ____________________________________________
# ------- Score = f1_macro-------
#
# > Fold = RepeatedStratifiedKFold(n_repeats=10, n_splits=5, random_state=None)
#
# > Best Parameter set:
#
# {'metric': 'minkowski', 'n_neighbors': 1, 'weights': 'distance'}
#
# > Grid scores:
#
# ...........RESULTS FOR TRAINING.........
# ........................................
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 1, 'weights': 'distance'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 1, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 5, 'weights': 'distance'}
# 0.741 (+/-0.066) for {'metric': 'minkowski', 'n_neighbors': 5, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 10, 'weights': 'distance'}
# 0.631 (+/-0.116) for {'metric': 'minkowski', 'n_neighbors': 10, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 15, 'weights': 'distance'}
# 0.629 (+/-0.108) for {'metric': 'minkowski', 'n_neighbors': 15, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 20, 'weights': 'distance'}
# 0.568 (+/-0.105) for {'metric': 'minkowski', 'n_neighbors': 20, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 1, 'weights': 'distance'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 1, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'distance'}
# 0.730 (+/-0.078) for {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 10, 'weights': 'distance'}
# 0.623 (+/-0.098) for {'metric': 'manhattan', 'n_neighbors': 10, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 15, 'weights': 'distance'}
# 0.631 (+/-0.098) for {'metric': 'manhattan', 'n_neighbors': 15, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 20, 'weights': 'distance'}
# 0.553 (+/-0.083) for {'metric': 'manhattan', 'n_neighbors': 20, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 1, 'weights': 'distance'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 1, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 5, 'weights': 'distance'}
# 0.741 (+/-0.066) for {'metric': 'euclidean', 'n_neighbors': 5, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 10, 'weights': 'distance'}
# 0.631 (+/-0.116) for {'metric': 'euclidean', 'n_neighbors': 10, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 15, 'weights': 'distance'}
# 0.629 (+/-0.108) for {'metric': 'euclidean', 'n_neighbors': 15, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 20, 'weights': 'distance'}
# 0.568 (+/-0.105) for {'metric': 'euclidean', 'n_neighbors': 20, 'weights': 'uniform'}
# ____________________________________________ END GRID SEARCH ____________________________________________

# %%
#KNN
clf = KNeighborsClassifier(n_neighbors=5, weights='uniform', metric='minkowski')
clf.fit(X_res, y_res)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# Accuracy 0.56
# F1-score [0.70943396 0.09411765]
#               precision    recall  f1-score   support
#
#            0       0.97      0.56      0.71       336
#            1       0.05      0.57      0.09        14
#
#     accuracy                           0.56       350
#    macro avg       0.51      0.57      0.40       350
# weighted avg       0.93      0.56      0.68       350

# %% [markdown]
# Condensed Nearest Neighbors

# %%
import warnings
warnings.simplefilter("ignore")

# %%
cnn = CondensedNearestNeighbour(random_state=42, n_jobs=10)   #n_jobs numero di processori da utilizzare 
X_res, y_res = cnn.fit_resample(X_train, y_train['emotional_intensity'])
print('Resampled dataset shape %s' % Counter(y_res))
# Out:
# Resampled dataset shape Counter({0: 149, 1: 41})

# %%
pca = PCA(n_components=2)
pca.fit(X_train)
X_pca = pca.transform(X_res)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_res, cmap=plt.cm.prism, edgecolor='k', alpha=0.7)
plt.show()

# %%
"""check_params ={"criterion":["gini", "entropy"],
         "max_depth":[4, 6, 8, 10],
         "min_samples_split": [5, 10, 15, 20],
         "min_samples_leaf": [3, 5, 7, 9, 11]}

dt=DecisionTreeClassifier()
          
results = customGridSearch(X_res, y_res, dt, check_params, "f1_macro")"""
# Out:
# ____________________________________________ START GRID SEARCH ____________________________________________
# ------- Score = f1_macro-------
#
# > Fold = RepeatedStratifiedKFold(n_repeats=10, n_splits=5, random_state=None)
#
# > Best Parameter set:
#
# {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 15}
#
# > Grid scores:
#
# ...........RESULTS FOR TRAINING.........
# ........................................
# 0.835 (+/-0.095) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.833 (+/-0.094) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.815 (+/-0.095) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.798 (+/-0.085) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.828 (+/-0.075) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.828 (+/-0.074) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.806 (+/-0.080) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.774 (+/-0.085) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.797 (+/-0.054) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.796 (+/-0.052) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.792 (+/-0.066) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.752 (+/-0.093) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.758 (+/-0.079) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.759 (+/-0.081) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.758 (+/-0.079) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.747 (+/-0.087) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.740 (+/-0.074) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.743 (+/-0.071) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.743 (+/-0.067) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.744 (+/-0.070) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.899 (+/-0.062) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.885 (+/-0.055) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.852 (+/-0.081) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.829 (+/-0.069) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.859 (+/-0.052) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.861 (+/-0.055) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.823 (+/-0.073) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.786 (+/-0.083) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.815 (+/-0.065) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.813 (+/-0.062) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.808 (+/-0.075) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.762 (+/-0.101) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.767 (+/-0.089) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.769 (+/-0.088) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.770 (+/-0.089) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.754 (+/-0.091) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.743 (+/-0.070) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.744 (+/-0.071) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.741 (+/-0.075) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.745 (+/-0.071) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.922 (+/-0.051) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.895 (+/-0.054) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.856 (+/-0.076) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.836 (+/-0.069) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.869 (+/-0.052) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.872 (+/-0.049) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.824 (+/-0.074) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.788 (+/-0.085) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.816 (+/-0.064) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.814 (+/-0.063) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.811 (+/-0.077) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.760 (+/-0.098) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.770 (+/-0.091) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.769 (+/-0.091) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.769 (+/-0.091) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.754 (+/-0.090) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.745 (+/-0.072) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.742 (+/-0.076) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.744 (+/-0.077) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.743 (+/-0.071) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.930 (+/-0.044) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.901 (+/-0.045) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.858 (+/-0.081) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.832 (+/-0.073) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.868 (+/-0.051) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.869 (+/-0.052) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.828 (+/-0.068) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.789 (+/-0.085) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.814 (+/-0.064) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.815 (+/-0.065) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.811 (+/-0.079) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.762 (+/-0.097) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.770 (+/-0.089) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.769 (+/-0.088) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.768 (+/-0.090) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.753 (+/-0.089) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.742 (+/-0.077) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.742 (+/-0.077) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.744 (+/-0.069) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.743 (+/-0.071) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.830 (+/-0.127) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.828 (+/-0.118) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.814 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.793 (+/-0.103) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.812 (+/-0.106) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.815 (+/-0.105) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.799 (+/-0.092) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.780 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.799 (+/-0.101) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.798 (+/-0.104) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.797 (+/-0.101) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.782 (+/-0.105) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.786 (+/-0.091) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.783 (+/-0.099) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.786 (+/-0.090) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.777 (+/-0.104) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.766 (+/-0.104) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.765 (+/-0.103) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.764 (+/-0.105) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.765 (+/-0.103) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.909 (+/-0.087) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.900 (+/-0.085) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.867 (+/-0.094) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.837 (+/-0.093) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.884 (+/-0.072) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.883 (+/-0.072) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.856 (+/-0.090) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.825 (+/-0.092) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.851 (+/-0.073) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.850 (+/-0.073) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.844 (+/-0.076) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.824 (+/-0.081) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.823 (+/-0.079) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.825 (+/-0.076) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.822 (+/-0.079) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.813 (+/-0.091) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.794 (+/-0.092) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.794 (+/-0.091) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.793 (+/-0.091) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.793 (+/-0.091) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.949 (+/-0.052) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.931 (+/-0.056) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.895 (+/-0.085) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.862 (+/-0.092) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.913 (+/-0.047) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.912 (+/-0.046) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.877 (+/-0.078) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.841 (+/-0.079) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.871 (+/-0.063) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.870 (+/-0.062) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.865 (+/-0.066) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.836 (+/-0.078) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.835 (+/-0.071) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.835 (+/-0.071) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.836 (+/-0.072) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.827 (+/-0.075) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.800 (+/-0.077) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.801 (+/-0.078) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.801 (+/-0.079) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.800 (+/-0.077) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.961 (+/-0.031) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.944 (+/-0.040) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.905 (+/-0.078) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.864 (+/-0.090) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.917 (+/-0.040) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.917 (+/-0.036) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.877 (+/-0.075) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.840 (+/-0.087) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.872 (+/-0.063) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.873 (+/-0.059) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.868 (+/-0.063) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.837 (+/-0.074) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.838 (+/-0.072) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.837 (+/-0.070) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.835 (+/-0.071) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.828 (+/-0.076) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.801 (+/-0.079) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.802 (+/-0.078) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.800 (+/-0.076) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.800 (+/-0.077) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 20}
# ____________________________________________ END GRID SEARCH ____________________________________________

# %%
#results
# Out:
# {'f1_macro': {'criterion': 'gini',
#   'max_depth': 8,
#   'min_samples_leaf': 3,
#   'min_samples_split': 15}}

# %%
clf = DecisionTreeClassifier(criterion = 'gini', max_depth = 8, min_samples_leaf = 3, min_samples_split = 15, random_state=42)
clf.fit(X_res, y_res)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# Accuracy 0.9
# F1-score [0.94704992 0.1025641 ]
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.95       336
#            1       0.08      0.14      0.10        14
#
#     accuracy                           0.90       350
#    macro avg       0.52      0.54      0.52       350
# weighted avg       0.93      0.90      0.91       350

# %%
"""check_params = {'n_neighbors': [1, 5, 10, 15, 20], "weights":["distance", "uniform"], 'metric' :['minkowski', 'manhattan', 'euclidean']}

clf=KNeighborsClassifier()
          
results = customGridSearch(X_res, y_res, clf, check_params, "f1_macro")"""
# Out:
# ____________________________________________ START GRID SEARCH ____________________________________________
# ------- Score = f1_macro-------
#
# > Fold = RepeatedStratifiedKFold(n_repeats=10, n_splits=5, random_state=None)
#
# > Best Parameter set:
#
# {'metric': 'minkowski', 'n_neighbors': 5, 'weights': 'distance'}
#
# > Grid scores:
#
# ...........RESULTS FOR TRAINING.........
# ........................................
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 1, 'weights': 'distance'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 1, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 5, 'weights': 'distance'}
# 0.540 (+/-0.083) for {'metric': 'minkowski', 'n_neighbors': 5, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 10, 'weights': 'distance'}
# 0.446 (+/-0.025) for {'metric': 'minkowski', 'n_neighbors': 10, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 15, 'weights': 'distance'}
# 0.448 (+/-0.028) for {'metric': 'minkowski', 'n_neighbors': 15, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 20, 'weights': 'distance'}
# 0.440 (+/-0.002) for {'metric': 'minkowski', 'n_neighbors': 20, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 1, 'weights': 'distance'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 1, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'distance'}
# 0.534 (+/-0.078) for {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 10, 'weights': 'distance'}
# 0.449 (+/-0.034) for {'metric': 'manhattan', 'n_neighbors': 10, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 15, 'weights': 'distance'}
# 0.452 (+/-0.042) for {'metric': 'manhattan', 'n_neighbors': 15, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 20, 'weights': 'distance'}
# 0.440 (+/-0.002) for {'metric': 'manhattan', 'n_neighbors': 20, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 1, 'weights': 'distance'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 1, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 5, 'weights': 'distance'}
# 0.540 (+/-0.083) for {'metric': 'euclidean', 'n_neighbors': 5, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 10, 'weights': 'distance'}
# 0.446 (+/-0.025) for {'metric': 'euclidean', 'n_neighbors': 10, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 15, 'weights': 'distance'}
# 0.448 (+/-0.028) for {'metric': 'euclidean', 'n_neighbors': 15, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 20, 'weights': 'distance'}
# 0.440 (+/-0.002) for {'metric': 'euclidean', 'n_neighbors': 20, 'weights': 'uniform'}
# ____________________________________________ END GRID SEARCH ____________________________________________

# %%
#results
# Out:
# {'f1_macro': {'metric': 'minkowski', 'n_neighbors': 5, 'weights': 'distance'}}

# %%
#KNN
clf = KNeighborsClassifier(n_neighbors=5, weights='distance', metric='minkowski')
clf.fit(X_res, y_res)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# Accuracy 0.9542857142857143
# F1-score [0.97660819 0.        ]
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98       336
#            1       0.00      0.00      0.00        14
#
#     accuracy                           0.95       350
#    macro avg       0.48      0.50      0.49       350
# weighted avg       0.92      0.95      0.94       350

# %% [markdown]
# Tomek Links

# %%
tl = TomekLinks()
X_res, y_res = tl.fit_resample(X_train, y_train['emotional_intensity'])
print('Resampled dataset shape %s' % Counter(y_res))
# Out:
# Resampled dataset shape Counter({0: 979, 1: 41})

# %%
pca = PCA(n_components=2)
pca.fit(X_train)
X_pca = pca.transform(X_res)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_res, cmap=plt.cm.prism, edgecolor='k', alpha=0.7)
plt.show()

# %%
"""check_params ={"criterion":["gini", "entropy"],
         "max_depth":[4, 6, 8, 10],
         "min_samples_split": [5, 10, 15, 20],
         "min_samples_leaf": [3, 5, 7, 9, 11]}

dt=DecisionTreeClassifier()
          
results = customGridSearch(X_res, y_res, dt, check_params, "f1_macro")"""
# Out:
# ____________________________________________ START GRID SEARCH ____________________________________________
# ------- Score = f1_macro-------
#
# > Fold = RepeatedStratifiedKFold(n_repeats=10, n_splits=5, random_state=None)
#
# > Best Parameter set:
#
# {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 10}
#
# > Grid scores:
#
# ...........RESULTS FOR TRAINING.........
# ........................................
# 0.758 (+/-0.064) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.723 (+/-0.094) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.689 (+/-0.114) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.657 (+/-0.119) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.701 (+/-0.094) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.700 (+/-0.091) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.668 (+/-0.117) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.621 (+/-0.123) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.653 (+/-0.141) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.652 (+/-0.139) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.641 (+/-0.159) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.579 (+/-0.159) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.595 (+/-0.190) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.598 (+/-0.197) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.601 (+/-0.195) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.573 (+/-0.183) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.560 (+/-0.159) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.560 (+/-0.159) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.560 (+/-0.159) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.560 (+/-0.159) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.806 (+/-0.065) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.751 (+/-0.093) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.702 (+/-0.122) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.675 (+/-0.123) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.748 (+/-0.089) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.746 (+/-0.091) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.694 (+/-0.116) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.641 (+/-0.147) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.682 (+/-0.154) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.680 (+/-0.153) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.670 (+/-0.150) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.599 (+/-0.174) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.608 (+/-0.194) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.606 (+/-0.197) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.612 (+/-0.199) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.586 (+/-0.192) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.561 (+/-0.164) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.564 (+/-0.164) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.564 (+/-0.164) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.564 (+/-0.164) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.848 (+/-0.073) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.775 (+/-0.094) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.731 (+/-0.112) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.686 (+/-0.128) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.762 (+/-0.093) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.765 (+/-0.096) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.713 (+/-0.126) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.654 (+/-0.136) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.686 (+/-0.147) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.686 (+/-0.147) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.676 (+/-0.141) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.608 (+/-0.168) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.614 (+/-0.198) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.610 (+/-0.197) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.614 (+/-0.196) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.587 (+/-0.176) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.564 (+/-0.164) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.564 (+/-0.164) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.561 (+/-0.164) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.561 (+/-0.164) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.867 (+/-0.061) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.795 (+/-0.081) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.743 (+/-0.112) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.698 (+/-0.127) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.775 (+/-0.087) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.775 (+/-0.087) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.719 (+/-0.111) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.665 (+/-0.138) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.690 (+/-0.142) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.689 (+/-0.140) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.681 (+/-0.146) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.605 (+/-0.169) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.609 (+/-0.196) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.614 (+/-0.196) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.611 (+/-0.199) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.590 (+/-0.183) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.561 (+/-0.164) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.564 (+/-0.164) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.564 (+/-0.164) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.561 (+/-0.164) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.809 (+/-0.146) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.792 (+/-0.141) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.773 (+/-0.137) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.744 (+/-0.184) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.776 (+/-0.132) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.776 (+/-0.133) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.756 (+/-0.121) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.730 (+/-0.182) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.761 (+/-0.107) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.760 (+/-0.106) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.754 (+/-0.104) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.716 (+/-0.179) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.728 (+/-0.147) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.726 (+/-0.146) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.728 (+/-0.147) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.714 (+/-0.171) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.691 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.691 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.691 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.691 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.895 (+/-0.096) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.863 (+/-0.087) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.834 (+/-0.099) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.799 (+/-0.149) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.843 (+/-0.098) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.844 (+/-0.097) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.810 (+/-0.107) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.771 (+/-0.156) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.807 (+/-0.095) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.805 (+/-0.093) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.798 (+/-0.092) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.757 (+/-0.155) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.760 (+/-0.140) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.757 (+/-0.141) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.759 (+/-0.140) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.740 (+/-0.156) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.713 (+/-0.136) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.713 (+/-0.136) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.713 (+/-0.136) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.713 (+/-0.136) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.933 (+/-0.059) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.894 (+/-0.067) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.855 (+/-0.088) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.815 (+/-0.135) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.876 (+/-0.069) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.877 (+/-0.071) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.832 (+/-0.090) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.783 (+/-0.158) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.830 (+/-0.079) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.829 (+/-0.079) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.819 (+/-0.091) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.768 (+/-0.141) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.775 (+/-0.098) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.778 (+/-0.099) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.776 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.755 (+/-0.119) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.731 (+/-0.101) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.731 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.730 (+/-0.099) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.728 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.947 (+/-0.033) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.902 (+/-0.052) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.864 (+/-0.078) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.814 (+/-0.144) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.884 (+/-0.062) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.885 (+/-0.063) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.840 (+/-0.085) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.784 (+/-0.156) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.833 (+/-0.080) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.833 (+/-0.080) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.825 (+/-0.093) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.772 (+/-0.135) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.780 (+/-0.099) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.780 (+/-0.099) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.783 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.763 (+/-0.115) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.733 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.730 (+/-0.099) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.731 (+/-0.101) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.733 (+/-0.099) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 20}
# ____________________________________________ END GRID SEARCH ____________________________________________

# %%
#results
# Out:
# {'f1_macro': {'criterion': 'entropy',
#   'max_depth': 6,
#   'min_samples_leaf': 7,
#   'min_samples_split': 10}}

# %%
clf = DecisionTreeClassifier(criterion = 'entropy',max_depth = 6, min_samples_leaf= 7, min_samples_split = 10, random_state=42)
clf.fit(X_res, y_res)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# Accuracy 0.9142857142857143
# F1-score [0.95440729 0.28571429]
#               precision    recall  f1-score   support
#
#            0       0.98      0.93      0.95       336
#            1       0.21      0.43      0.29        14
#
#     accuracy                           0.91       350
#    macro avg       0.59      0.68      0.62       350
# weighted avg       0.94      0.91      0.93       350

# %%
"""check_params = {'n_neighbors': [1, 5, 10, 15, 20], "weights":["distance", "uniform"], 'metric' :['minkowski', 'manhattan', 'euclidean']}

clf=KNeighborsClassifier()
          
results = customGridSearch(X_res, y_res, clf, check_params, "f1_macro")"""
# Out:
# ____________________________________________ START GRID SEARCH ____________________________________________
# ------- Score = f1_macro-------
#
# > Fold = RepeatedStratifiedKFold(n_repeats=10, n_splits=5, random_state=None)
#
# > Best Parameter set:
#
# {'metric': 'minkowski', 'n_neighbors': 1, 'weights': 'distance'}
#
# > Grid scores:
#
# ...........RESULTS FOR TRAINING.........
# ........................................
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 1, 'weights': 'distance'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 1, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 5, 'weights': 'distance'}
# 0.490 (+/-0.008) for {'metric': 'minkowski', 'n_neighbors': 5, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 10, 'weights': 'distance'}
# 0.490 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 10, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 15, 'weights': 'distance'}
# 0.490 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 15, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 20, 'weights': 'distance'}
# 0.490 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 20, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 1, 'weights': 'distance'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 1, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'distance'}
# 0.517 (+/-0.042) for {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 10, 'weights': 'distance'}
# 0.490 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 10, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 15, 'weights': 'distance'}
# 0.490 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 15, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 20, 'weights': 'distance'}
# 0.490 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 20, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 1, 'weights': 'distance'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 1, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 5, 'weights': 'distance'}
# 0.490 (+/-0.008) for {'metric': 'euclidean', 'n_neighbors': 5, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 10, 'weights': 'distance'}
# 0.490 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 10, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 15, 'weights': 'distance'}
# 0.490 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 15, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 20, 'weights': 'distance'}
# 0.490 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 20, 'weights': 'uniform'}
# ____________________________________________ END GRID SEARCH ____________________________________________

# %%
#KNN
clf = KNeighborsClassifier(n_neighbors=5, weights='uniform', metric='minkowski')
clf.fit(X_res, y_res)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# Accuracy 0.96
# F1-score [0.97959184 0.        ]
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       336
#            1       0.00      0.00      0.00        14
#
#     accuracy                           0.96       350
#    macro avg       0.48      0.50      0.49       350
# weighted avg       0.92      0.96      0.94       350

# %% [markdown]
# Edit Nearest Neighbours

# %%
enn = EditedNearestNeighbours()
X_res, y_res = enn.fit_resample(X_train, y_train['emotional_intensity'])
print('Resampled dataset shape %s' % Counter(y_res))
# Out:
# Resampled dataset shape Counter({0: 935, 1: 41})

# %%
pca = PCA(n_components=2)
pca.fit(X_train)
X_pca = pca.transform(X_res)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_res, cmap=plt.cm.prism, edgecolor='k', alpha=0.7)
plt.show()

# %%
"""check_params ={"criterion":["gini", "entropy"],
         "max_depth":[4, 6, 8, 10],
         "min_samples_split": [5, 10, 15, 20],
         "min_samples_leaf": [3, 5, 7, 9, 11]}

dt=DecisionTreeClassifier()
          
results = customGridSearch(X_res, y_res, dt, check_params, "f1_macro")"""
# Out:
# ____________________________________________ START GRID SEARCH ____________________________________________
# ------- Score = f1_macro-------
#
# > Fold = RepeatedStratifiedKFold(n_repeats=10, n_splits=5, random_state=None)
#
# > Best Parameter set:
#
# {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 5}
#
# > Grid scores:
#
# ...........RESULTS FOR TRAINING.........
# ........................................
# 0.769 (+/-0.071) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.741 (+/-0.098) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.705 (+/-0.124) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.681 (+/-0.138) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.719 (+/-0.091) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.719 (+/-0.091) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.684 (+/-0.126) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.651 (+/-0.166) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.681 (+/-0.148) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.681 (+/-0.148) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.678 (+/-0.156) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.640 (+/-0.186) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.647 (+/-0.184) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.649 (+/-0.178) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.647 (+/-0.184) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.643 (+/-0.171) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.623 (+/-0.184) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.627 (+/-0.189) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.623 (+/-0.183) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.620 (+/-0.188) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.819 (+/-0.072) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.770 (+/-0.085) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.727 (+/-0.122) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.704 (+/-0.149) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.751 (+/-0.096) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.753 (+/-0.094) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.704 (+/-0.146) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.668 (+/-0.179) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.707 (+/-0.150) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.707 (+/-0.150) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.698 (+/-0.168) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.655 (+/-0.185) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.663 (+/-0.170) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.662 (+/-0.170) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.664 (+/-0.171) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.656 (+/-0.164) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.632 (+/-0.197) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.630 (+/-0.195) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.633 (+/-0.197) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.632 (+/-0.196) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.850 (+/-0.069) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.786 (+/-0.083) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.734 (+/-0.127) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.707 (+/-0.153) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.767 (+/-0.094) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.767 (+/-0.096) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.716 (+/-0.148) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.675 (+/-0.181) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.712 (+/-0.147) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.707 (+/-0.160) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.705 (+/-0.169) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.659 (+/-0.176) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.665 (+/-0.172) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.665 (+/-0.171) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.664 (+/-0.171) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.658 (+/-0.165) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.629 (+/-0.194) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.629 (+/-0.193) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.630 (+/-0.194) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.634 (+/-0.199) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.871 (+/-0.054) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.801 (+/-0.083) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.742 (+/-0.127) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.713 (+/-0.153) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.776 (+/-0.088) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.778 (+/-0.088) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.728 (+/-0.135) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.687 (+/-0.162) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.712 (+/-0.150) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.712 (+/-0.161) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.703 (+/-0.169) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.660 (+/-0.177) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.663 (+/-0.171) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.665 (+/-0.171) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.665 (+/-0.171) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.657 (+/-0.164) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.632 (+/-0.197) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.629 (+/-0.194) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.632 (+/-0.197) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.631 (+/-0.195) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.823 (+/-0.125) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.804 (+/-0.106) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.781 (+/-0.120) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.755 (+/-0.177) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.796 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.795 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.773 (+/-0.124) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.744 (+/-0.182) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.764 (+/-0.106) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.765 (+/-0.105) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.759 (+/-0.118) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.731 (+/-0.170) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.730 (+/-0.135) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.730 (+/-0.135) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.729 (+/-0.132) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.721 (+/-0.162) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.707 (+/-0.148) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.707 (+/-0.148) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.709 (+/-0.148) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.705 (+/-0.146) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.899 (+/-0.093) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.866 (+/-0.094) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.836 (+/-0.096) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.792 (+/-0.136) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.846 (+/-0.087) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.847 (+/-0.087) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.816 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.769 (+/-0.155) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.812 (+/-0.089) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.811 (+/-0.090) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.804 (+/-0.099) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.757 (+/-0.153) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.758 (+/-0.123) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.758 (+/-0.124) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.756 (+/-0.122) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.741 (+/-0.168) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.724 (+/-0.156) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.722 (+/-0.157) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.722 (+/-0.157) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.726 (+/-0.158) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.934 (+/-0.054) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.899 (+/-0.059) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.860 (+/-0.072) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.811 (+/-0.101) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.877 (+/-0.059) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.876 (+/-0.059) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.840 (+/-0.082) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.778 (+/-0.136) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.832 (+/-0.072) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.831 (+/-0.073) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.824 (+/-0.090) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.766 (+/-0.139) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.767 (+/-0.124) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.766 (+/-0.124) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.766 (+/-0.125) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.748 (+/-0.141) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.738 (+/-0.136) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.738 (+/-0.138) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.736 (+/-0.138) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.735 (+/-0.136) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.945 (+/-0.040) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.904 (+/-0.059) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.864 (+/-0.070) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.816 (+/-0.096) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.887 (+/-0.055) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.887 (+/-0.057) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.847 (+/-0.067) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.782 (+/-0.134) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.841 (+/-0.068) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.838 (+/-0.075) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.836 (+/-0.072) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.776 (+/-0.121) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.774 (+/-0.127) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.775 (+/-0.124) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.777 (+/-0.126) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.758 (+/-0.143) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.742 (+/-0.142) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.742 (+/-0.140) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.743 (+/-0.142) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.744 (+/-0.141) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 20}
# ____________________________________________ END GRID SEARCH ____________________________________________

# %%
#results
# Out:
# {'f1_macro': {'criterion': 'gini',
#   'max_depth': 10,
#   'min_samples_leaf': 3,
#   'min_samples_split': 5}}

# %%
clf = DecisionTreeClassifier(criterion = 'gini', max_depth = 10, min_samples_leaf = 3, min_samples_split = 5, random_state=42)
clf.fit(X_res, y_res)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# Accuracy 0.9142857142857143
# F1-score [0.95481928 0.16666667]
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.95       336
#            1       0.14      0.21      0.17        14
#
#     accuracy                           0.91       350
#    macro avg       0.55      0.58      0.56       350
# weighted avg       0.93      0.91      0.92       350

# %%
"""check_params = {'n_neighbors': [1, 5, 10, 15, 20], "weights":["distance", "uniform"], 'metric' :['minkowski', 'manhattan', 'euclidean']}

clf=KNeighborsClassifier()
          
results = customGridSearch(X_res, y_res, clf, check_params, "f1_macro")"""
# Out:
# ____________________________________________ START GRID SEARCH ____________________________________________
# ------- Score = f1_macro-------
#
# > Fold = RepeatedStratifiedKFold(n_repeats=10, n_splits=5, random_state=None)
#
# > Best Parameter set:
#
# {'metric': 'minkowski', 'n_neighbors': 1, 'weights': 'distance'}
#
# > Grid scores:
#
# ...........RESULTS FOR TRAINING.........
# ........................................
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 1, 'weights': 'distance'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 1, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 5, 'weights': 'distance'}
# 0.495 (+/-0.023) for {'metric': 'minkowski', 'n_neighbors': 5, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 10, 'weights': 'distance'}
# 0.489 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 10, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 15, 'weights': 'distance'}
# 0.489 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 15, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 20, 'weights': 'distance'}
# 0.489 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 20, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 1, 'weights': 'distance'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 1, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'distance'}
# 0.526 (+/-0.043) for {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 10, 'weights': 'distance'}
# 0.489 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 10, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 15, 'weights': 'distance'}
# 0.489 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 15, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 20, 'weights': 'distance'}
# 0.489 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 20, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 1, 'weights': 'distance'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 1, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 5, 'weights': 'distance'}
# 0.495 (+/-0.023) for {'metric': 'euclidean', 'n_neighbors': 5, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 10, 'weights': 'distance'}
# 0.489 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 10, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 15, 'weights': 'distance'}
# 0.489 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 15, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 20, 'weights': 'distance'}
# 0.489 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 20, 'weights': 'uniform'}
# ____________________________________________ END GRID SEARCH ____________________________________________

# %%
#KNN
clf = KNeighborsClassifier(n_neighbors=5, weights='distance', metric='minkowski')
clf.fit(X_res, y_res)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# Accuracy 0.96
# F1-score [0.97959184 0.        ]
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       336
#            1       0.00      0.00      0.00        14
#
#     accuracy                           0.96       350
#    macro avg       0.48      0.50      0.49       350
# weighted avg       0.92      0.96      0.94       350

# %% [markdown]
# Cluster Centroids

# %%
from sklearn.cluster import KMeans
from imblearn.under_sampling import ClusterCentroids
#l'unico che usa il k-means

# %%
cc = ClusterCentroids(estimator=KMeans(n_init=1, random_state=0), random_state=42)
X_res, y_res = cc.fit_resample(X_train, y_train['emotional_intensity'])
print('Resampled dataset shape %s' % Counter(y_res))
# Out:
# Resampled dataset shape Counter({0: 41, 1: 41})

# %%
pca = PCA(n_components=2)
pca.fit(X_train)
X_pca = pca.transform(X_res)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_res, cmap=plt.cm.prism, edgecolor='k', alpha=0.7)
plt.show()

# %%
"""check_params ={"criterion":["gini", "entropy"],
         "max_depth":[4, 6, 8, 10],
         "min_samples_split": [5, 10, 15, 20],
         "min_samples_leaf": [3, 5, 7, 9, 11]}

dt=DecisionTreeClassifier()
          
results = customGridSearch(X_res, y_res, dt, check_params, "f1_macro")"""
# Out:
# ____________________________________________ START GRID SEARCH ____________________________________________
# ------- Score = f1_macro-------
#
# > Fold = RepeatedStratifiedKFold(n_repeats=10, n_splits=5, random_state=None)
#
# > Best Parameter set:
#
# {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 5}
#
# > Grid scores:
#
# ...........RESULTS FOR TRAINING.........
# ........................................
# 0.960 (+/-0.039) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.942 (+/-0.047) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.919 (+/-0.051) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.914 (+/-0.051) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.915 (+/-0.048) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.915 (+/-0.046) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.896 (+/-0.047) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.892 (+/-0.046) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.882 (+/-0.047) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.882 (+/-0.048) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.879 (+/-0.049) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.871 (+/-0.041) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.857 (+/-0.051) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.858 (+/-0.049) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.857 (+/-0.051) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.855 (+/-0.049) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.841 (+/-0.064) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.840 (+/-0.064) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.841 (+/-0.064) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.840 (+/-0.064) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.959 (+/-0.038) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.941 (+/-0.047) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.919 (+/-0.050) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.914 (+/-0.051) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.915 (+/-0.046) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.915 (+/-0.048) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.896 (+/-0.048) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.892 (+/-0.046) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.882 (+/-0.048) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.882 (+/-0.048) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.879 (+/-0.048) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.871 (+/-0.041) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.858 (+/-0.049) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.857 (+/-0.051) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.858 (+/-0.049) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.855 (+/-0.049) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.841 (+/-0.064) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.841 (+/-0.064) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.840 (+/-0.064) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.841 (+/-0.064) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.959 (+/-0.037) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.943 (+/-0.047) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.919 (+/-0.051) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.913 (+/-0.051) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.915 (+/-0.048) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.914 (+/-0.047) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.896 (+/-0.047) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.892 (+/-0.046) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.882 (+/-0.047) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.882 (+/-0.048) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.879 (+/-0.048) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.871 (+/-0.041) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.858 (+/-0.049) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.857 (+/-0.051) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.857 (+/-0.051) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.856 (+/-0.048) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.840 (+/-0.064) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.840 (+/-0.064) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.840 (+/-0.064) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.840 (+/-0.064) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.959 (+/-0.037) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.942 (+/-0.048) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.919 (+/-0.050) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.913 (+/-0.050) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.915 (+/-0.048) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.915 (+/-0.046) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.896 (+/-0.047) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.892 (+/-0.046) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.882 (+/-0.048) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.882 (+/-0.047) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.879 (+/-0.048) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.871 (+/-0.041) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.857 (+/-0.051) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.858 (+/-0.049) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.858 (+/-0.049) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.855 (+/-0.049) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.840 (+/-0.064) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.841 (+/-0.064) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.840 (+/-0.064) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.841 (+/-0.064) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.969 (+/-0.034) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.953 (+/-0.043) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.916 (+/-0.071) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.899 (+/-0.072) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.935 (+/-0.038) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.935 (+/-0.039) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.907 (+/-0.059) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.887 (+/-0.064) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.904 (+/-0.049) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.904 (+/-0.049) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.895 (+/-0.058) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.878 (+/-0.060) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.874 (+/-0.055) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.875 (+/-0.057) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.875 (+/-0.056) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.868 (+/-0.061) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.845 (+/-0.075) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.844 (+/-0.074) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.844 (+/-0.075) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.844 (+/-0.074) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.971 (+/-0.030) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.955 (+/-0.040) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.917 (+/-0.071) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.898 (+/-0.070) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.935 (+/-0.038) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.936 (+/-0.038) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.908 (+/-0.059) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.887 (+/-0.063) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.904 (+/-0.049) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.904 (+/-0.048) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.895 (+/-0.058) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.879 (+/-0.058) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.874 (+/-0.055) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.874 (+/-0.054) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.875 (+/-0.056) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.868 (+/-0.061) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.844 (+/-0.075) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.844 (+/-0.075) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.844 (+/-0.075) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.844 (+/-0.074) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.971 (+/-0.030) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.956 (+/-0.042) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.917 (+/-0.071) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.899 (+/-0.072) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.936 (+/-0.038) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.937 (+/-0.040) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.907 (+/-0.061) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.888 (+/-0.064) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.904 (+/-0.049) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.905 (+/-0.049) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.896 (+/-0.057) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.878 (+/-0.060) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.876 (+/-0.057) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.874 (+/-0.054) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.874 (+/-0.054) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.868 (+/-0.060) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.844 (+/-0.074) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.844 (+/-0.075) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.845 (+/-0.075) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.844 (+/-0.075) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.972 (+/-0.029) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.955 (+/-0.042) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.916 (+/-0.070) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.899 (+/-0.073) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.936 (+/-0.040) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.935 (+/-0.038) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.907 (+/-0.061) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.888 (+/-0.065) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.905 (+/-0.050) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.903 (+/-0.048) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.896 (+/-0.060) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.879 (+/-0.059) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.875 (+/-0.057) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.876 (+/-0.058) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.876 (+/-0.056) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.866 (+/-0.057) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.844 (+/-0.075) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.844 (+/-0.074) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.844 (+/-0.075) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.844 (+/-0.075) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 20}
# ____________________________________________ END GRID SEARCH ____________________________________________

# %%
#results
# Out:
# {'f1_macro': {'criterion': 'entropy',
#   'max_depth': 8,
#   'min_samples_leaf': 3,
#   'min_samples_split': 5}}

# %%
clf = DecisionTreeClassifier(criterion = 'entropy', max_depth = 8, min_samples_leaf = 3, min_samples_split = 5, random_state=42)
clf.fit(X_res, y_res)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# Accuracy 0.30857142857142855
# F1-score [0.44495413 0.08333333]
#               precision    recall  f1-score   support
#
#            0       0.97      0.29      0.44       336
#            1       0.04      0.79      0.08        14
#
#     accuracy                           0.31       350
#    macro avg       0.51      0.54      0.26       350
# weighted avg       0.93      0.31      0.43       350

# %%
"""check_params = {'n_neighbors': [1, 5, 10, 15, 20], "weights":["distance", "uniform"], 'metric' :['minkowski', 'manhattan', 'euclidean']}

clf=KNeighborsClassifier()
          
results = customGridSearch(X_res, y_res, clf, check_params, "f1_macro")"""
# Out:
# ____________________________________________ START GRID SEARCH ____________________________________________
# ------- Score = f1_macro-------
#
# > Fold = RepeatedStratifiedKFold(n_repeats=10, n_splits=5, random_state=None)
#
# > Best Parameter set:
#
# {'metric': 'manhattan', 'n_neighbors': 10, 'weights': 'distance'}
#
# > Grid scores:
#
# ...........RESULTS FOR TRAINING.........
# ........................................
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 1, 'weights': 'distance'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 1, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 5, 'weights': 'distance'}
# 0.572 (+/-0.111) for {'metric': 'minkowski', 'n_neighbors': 5, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 10, 'weights': 'distance'}
# 0.432 (+/-0.092) for {'metric': 'minkowski', 'n_neighbors': 10, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 15, 'weights': 'distance'}
# 0.470 (+/-0.103) for {'metric': 'minkowski', 'n_neighbors': 15, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 20, 'weights': 'distance'}
# 0.423 (+/-0.087) for {'metric': 'minkowski', 'n_neighbors': 20, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 1, 'weights': 'distance'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 1, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'distance'}
# 0.587 (+/-0.110) for {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 10, 'weights': 'distance'}
# 0.501 (+/-0.099) for {'metric': 'manhattan', 'n_neighbors': 10, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 15, 'weights': 'distance'}
# 0.538 (+/-0.120) for {'metric': 'manhattan', 'n_neighbors': 15, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 20, 'weights': 'distance'}
# 0.455 (+/-0.098) for {'metric': 'manhattan', 'n_neighbors': 20, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 1, 'weights': 'distance'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 1, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 5, 'weights': 'distance'}
# 0.572 (+/-0.111) for {'metric': 'euclidean', 'n_neighbors': 5, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 10, 'weights': 'distance'}
# 0.432 (+/-0.092) for {'metric': 'euclidean', 'n_neighbors': 10, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 15, 'weights': 'distance'}
# 0.470 (+/-0.103) for {'metric': 'euclidean', 'n_neighbors': 15, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 20, 'weights': 'distance'}
# 0.423 (+/-0.087) for {'metric': 'euclidean', 'n_neighbors': 20, 'weights': 'uniform'}
# ____________________________________________ END GRID SEARCH ____________________________________________

# %%
#KNN
clf = KNeighborsClassifier(n_neighbors=10, weights='distance', metric='manhattan')
clf.fit(X_res, y_res)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# Accuracy 0.9514285714285714
# F1-score [0.97488922 0.26086957]
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97       336
#            1       0.33      0.21      0.26        14
#
#     accuracy                           0.95       350
#    macro avg       0.65      0.60      0.62       350
# weighted avg       0.94      0.95      0.95       350

# %% [markdown]
#   OVERSAMPLING

# %%
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import ADASYN

# %% [markdown]
# RandomOverSampler

# %%
ros = RandomOverSampler(random_state=42)
X_res, y_res = ros.fit_resample(X_train, y_train['emotional_intensity'])
print('Resampled dataset shape %s' % Counter(y_res))
# Out:
# Resampled dataset shape Counter({0: 984, 1: 984})

# %%
pca = PCA(n_components=2)
pca.fit(X_train)
X_pca = pca.transform(X_res)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_res, cmap=plt.cm.prism, edgecolor='k', alpha=0.7)
plt.show()

# %%
check_params ={"criterion":["gini", "entropy"],
         "max_depth":[4, 6, 8, 10],
         "min_samples_split": [5, 10, 15, 20],
         "min_samples_leaf": [3, 5, 7, 9, 11]}

dt=DecisionTreeClassifier()
          
results = customGridSearch(X_res, y_res, dt, check_params, "f1_macro")
# Out:
# ____________________________________________ START GRID SEARCH ____________________________________________
# ------- Score = f1_macro-------
#
# > Fold = RepeatedStratifiedKFold(n_repeats=10, n_splits=5, random_state=None)
#
# > Best Parameter set:
#
# {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 5}
#
# > Grid scores:
#
# ...........RESULTS FOR TRAINING.........
# ........................................
# 0.894 (+/-0.028) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.893 (+/-0.028) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.893 (+/-0.028) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.894 (+/-0.028) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.892 (+/-0.029) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.892 (+/-0.029) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.892 (+/-0.029) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.892 (+/-0.029) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.892 (+/-0.029) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.892 (+/-0.029) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.892 (+/-0.029) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.892 (+/-0.029) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.891 (+/-0.029) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.891 (+/-0.029) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.891 (+/-0.029) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.891 (+/-0.029) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.889 (+/-0.029) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.889 (+/-0.029) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.889 (+/-0.029) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.889 (+/-0.029) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.974 (+/-0.017) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.974 (+/-0.018) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.974 (+/-0.018) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.974 (+/-0.018) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.971 (+/-0.018) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.971 (+/-0.017) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.971 (+/-0.018) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.971 (+/-0.018) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.969 (+/-0.018) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.969 (+/-0.018) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.969 (+/-0.018) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.969 (+/-0.019) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.966 (+/-0.018) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.967 (+/-0.019) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.966 (+/-0.019) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.966 (+/-0.018) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.965 (+/-0.021) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.964 (+/-0.021) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.964 (+/-0.020) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.964 (+/-0.021) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.991 (+/-0.009) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.991 (+/-0.009) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.991 (+/-0.009) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.991 (+/-0.009) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.988 (+/-0.009) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.988 (+/-0.009) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.988 (+/-0.009) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.986 (+/-0.011) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.985 (+/-0.012) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.984 (+/-0.011) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.984 (+/-0.012) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.984 (+/-0.011) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.979 (+/-0.014) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.978 (+/-0.014) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.978 (+/-0.014) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.978 (+/-0.014) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.975 (+/-0.014) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.975 (+/-0.014) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.975 (+/-0.014) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.976 (+/-0.013) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.996 (+/-0.005) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.996 (+/-0.005) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.995 (+/-0.006) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.994 (+/-0.006) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.990 (+/-0.006) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.990 (+/-0.007) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.990 (+/-0.007) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.989 (+/-0.008) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.986 (+/-0.009) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.986 (+/-0.009) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.987 (+/-0.009) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.986 (+/-0.010) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.979 (+/-0.013) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.979 (+/-0.013) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.979 (+/-0.012) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.980 (+/-0.013) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.976 (+/-0.013) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.976 (+/-0.014) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.976 (+/-0.013) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.976 (+/-0.013) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.852 (+/-0.037) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.852 (+/-0.037) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.852 (+/-0.037) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.852 (+/-0.038) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.851 (+/-0.038) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.851 (+/-0.038) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.852 (+/-0.038) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.851 (+/-0.038) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.851 (+/-0.038) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.851 (+/-0.038) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.851 (+/-0.038) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.851 (+/-0.038) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.851 (+/-0.038) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.851 (+/-0.039) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.851 (+/-0.039) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.851 (+/-0.039) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.848 (+/-0.039) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.848 (+/-0.038) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.848 (+/-0.038) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.848 (+/-0.038) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.938 (+/-0.041) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.938 (+/-0.041) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.938 (+/-0.041) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.938 (+/-0.041) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.936 (+/-0.042) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.937 (+/-0.041) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.936 (+/-0.041) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.936 (+/-0.042) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.937 (+/-0.042) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.937 (+/-0.042) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.937 (+/-0.042) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.937 (+/-0.042) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.937 (+/-0.042) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.937 (+/-0.042) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.937 (+/-0.042) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.937 (+/-0.042) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.933 (+/-0.042) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.933 (+/-0.042) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.934 (+/-0.042) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.934 (+/-0.042) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.975 (+/-0.033) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.976 (+/-0.034) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.975 (+/-0.033) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.975 (+/-0.033) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.975 (+/-0.033) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.975 (+/-0.033) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.975 (+/-0.033) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.974 (+/-0.034) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.973 (+/-0.032) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.973 (+/-0.032) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.973 (+/-0.031) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.973 (+/-0.032) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.970 (+/-0.032) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.971 (+/-0.032) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.970 (+/-0.033) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.969 (+/-0.033) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.967 (+/-0.030) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.966 (+/-0.030) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.966 (+/-0.029) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.965 (+/-0.030) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.990 (+/-0.020) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.990 (+/-0.020) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.990 (+/-0.020) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.990 (+/-0.020) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.988 (+/-0.020) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.987 (+/-0.020) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.988 (+/-0.020) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.987 (+/-0.020) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.986 (+/-0.018) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.986 (+/-0.019) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.985 (+/-0.019) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.985 (+/-0.019) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.981 (+/-0.018) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.981 (+/-0.018) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.981 (+/-0.018) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.981 (+/-0.018) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.977 (+/-0.018) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.977 (+/-0.018) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.976 (+/-0.018) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.977 (+/-0.018) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 20}
# ____________________________________________ END GRID SEARCH ____________________________________________

# %%
results
# Out:
# {'f1_macro': {'criterion': 'gini',
#   'max_depth': 10,
#   'min_samples_leaf': 3,
#   'min_samples_split': 5}}

# %%
clf = DecisionTreeClassifier(criterion = 'gini', max_depth = 10, min_samples_leaf = 3, min_samples_split = 5, random_state=42)
clf.fit(X_res, y_res)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# Accuracy 0.9285714285714286
# F1-score [0.96251874 0.24242424]
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96       336
#            1       0.21      0.29      0.24        14
#
#     accuracy                           0.93       350
#    macro avg       0.59      0.62      0.60       350
# weighted avg       0.94      0.93      0.93       350

# %%
check_params = {'n_neighbors': [1, 5, 10, 15, 20], "weights":["distance", "uniform"], 'metric' :['minkowski', 'manhattan', 'euclidean']}

clf=KNeighborsClassifier()
          
results = customGridSearch(X_res, y_res, clf, check_params, "f1_macro")
# Out:
# ____________________________________________ START GRID SEARCH ____________________________________________
# ------- Score = f1_macro-------
#
# > Fold = RepeatedStratifiedKFold(n_repeats=10, n_splits=5, random_state=None)
#
# > Best Parameter set:
#
# {'metric': 'minkowski', 'n_neighbors': 1, 'weights': 'distance'}
#
# > Grid scores:
#
# ...........RESULTS FOR TRAINING.........
# ........................................
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 1, 'weights': 'distance'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 1, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 5, 'weights': 'distance'}
# 0.980 (+/-0.004) for {'metric': 'minkowski', 'n_neighbors': 5, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 10, 'weights': 'distance'}
# 0.955 (+/-0.005) for {'metric': 'minkowski', 'n_neighbors': 10, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 15, 'weights': 'distance'}
# 0.917 (+/-0.008) for {'metric': 'minkowski', 'n_neighbors': 15, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 20, 'weights': 'distance'}
# 0.891 (+/-0.008) for {'metric': 'minkowski', 'n_neighbors': 20, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 1, 'weights': 'distance'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 1, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'distance'}
# 0.982 (+/-0.003) for {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 10, 'weights': 'distance'}
# 0.959 (+/-0.005) for {'metric': 'manhattan', 'n_neighbors': 10, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 15, 'weights': 'distance'}
# 0.922 (+/-0.006) for {'metric': 'manhattan', 'n_neighbors': 15, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 20, 'weights': 'distance'}
# 0.895 (+/-0.007) for {'metric': 'manhattan', 'n_neighbors': 20, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 1, 'weights': 'distance'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 1, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 5, 'weights': 'distance'}
# 0.980 (+/-0.004) for {'metric': 'euclidean', 'n_neighbors': 5, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 10, 'weights': 'distance'}
# 0.955 (+/-0.005) for {'metric': 'euclidean', 'n_neighbors': 10, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 15, 'weights': 'distance'}
# 0.917 (+/-0.008) for {'metric': 'euclidean', 'n_neighbors': 15, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 20, 'weights': 'distance'}
# 0.891 (+/-0.008) for {'metric': 'euclidean', 'n_neighbors': 20, 'weights': 'uniform'}
# ____________________________________________ END GRID SEARCH ____________________________________________

# %%
#KNN
clf = KNeighborsClassifier(n_neighbors=5, weights='distance', metric='minkowski')
clf.fit(X_res, y_res)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# Accuracy 0.8857142857142857
# F1-score [0.93920973 0.04761905]
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94       336
#            1       0.04      0.07      0.05        14
#
#     accuracy                           0.89       350
#    macro avg       0.50      0.50      0.49       350
# weighted avg       0.92      0.89      0.90       350

# %% [markdown]
# SMOTE

# %%
sm = SMOTE(random_state=42)
X_res, y_res = sm.fit_resample(X_train, y_train['emotional_intensity'])
print('Resampled dataset shape %s' % Counter(y_res))
# Out:
# Resampled dataset shape Counter({0: 984, 1: 984})

# %%
pca = PCA(n_components=2)
pca.fit(X_train)
X_pca = pca.transform(X_res)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_res, cmap=plt.cm.prism, edgecolor='k', alpha=0.7)
plt.show()

# %%
check_params ={"criterion":["gini", "entropy"],
         "max_depth":[4, 6, 8, 10],
         "min_samples_split": [5, 10, 15, 20],
         "min_samples_leaf": [3, 5, 7, 9, 11]}

dt=DecisionTreeClassifier()
          
results = customGridSearch(X_res, y_res, dt, check_params, "f1_macro")
# Out:
# ____________________________________________ START GRID SEARCH ____________________________________________
# ------- Score = f1_macro-------
#
# > Fold = RepeatedStratifiedKFold(n_repeats=10, n_splits=5, random_state=None)
#
# > Best Parameter set:
#
# {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 5}
#
# > Grid scores:
#
# ...........RESULTS FOR TRAINING.........
# ........................................
# 0.871 (+/-0.029) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.870 (+/-0.031) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.870 (+/-0.030) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.870 (+/-0.032) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.869 (+/-0.031) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.870 (+/-0.031) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.870 (+/-0.030) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.869 (+/-0.031) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.868 (+/-0.032) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.868 (+/-0.031) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.868 (+/-0.030) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.868 (+/-0.032) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.866 (+/-0.031) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.866 (+/-0.031) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.866 (+/-0.031) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.866 (+/-0.032) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.865 (+/-0.031) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.865 (+/-0.031) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.865 (+/-0.031) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.865 (+/-0.031) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.926 (+/-0.035) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.926 (+/-0.035) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.925 (+/-0.035) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.923 (+/-0.034) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.923 (+/-0.034) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.924 (+/-0.034) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.923 (+/-0.033) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.922 (+/-0.034) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.921 (+/-0.032) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.921 (+/-0.032) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.921 (+/-0.032) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.920 (+/-0.032) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.918 (+/-0.031) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.918 (+/-0.031) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.918 (+/-0.031) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.918 (+/-0.030) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.915 (+/-0.029) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.914 (+/-0.028) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.914 (+/-0.028) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.915 (+/-0.029) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.953 (+/-0.029) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.952 (+/-0.028) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.950 (+/-0.028) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.948 (+/-0.027) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.948 (+/-0.026) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.948 (+/-0.027) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.947 (+/-0.026) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.945 (+/-0.025) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.942 (+/-0.025) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.942 (+/-0.025) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.943 (+/-0.025) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.941 (+/-0.024) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.937 (+/-0.025) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.937 (+/-0.024) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.937 (+/-0.025) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.937 (+/-0.023) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.932 (+/-0.022) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.932 (+/-0.022) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.931 (+/-0.023) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.931 (+/-0.022) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.965 (+/-0.020) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.965 (+/-0.020) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.962 (+/-0.020) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.960 (+/-0.020) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.960 (+/-0.018) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.960 (+/-0.019) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.958 (+/-0.018) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.956 (+/-0.018) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.953 (+/-0.017) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.954 (+/-0.017) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.953 (+/-0.017) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.952 (+/-0.016) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.948 (+/-0.016) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.947 (+/-0.017) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.947 (+/-0.016) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.947 (+/-0.016) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.942 (+/-0.015) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.942 (+/-0.015) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.942 (+/-0.015) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.942 (+/-0.015) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.843 (+/-0.028) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.842 (+/-0.027) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.841 (+/-0.028) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.841 (+/-0.027) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.842 (+/-0.028) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.842 (+/-0.028) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.841 (+/-0.028) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.841 (+/-0.027) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.841 (+/-0.027) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.841 (+/-0.028) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.841 (+/-0.027) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.840 (+/-0.028) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.840 (+/-0.026) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.841 (+/-0.028) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.840 (+/-0.027) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.840 (+/-0.027) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.841 (+/-0.027) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.840 (+/-0.028) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.840 (+/-0.028) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.840 (+/-0.026) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.917 (+/-0.028) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.918 (+/-0.027) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.916 (+/-0.027) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.915 (+/-0.028) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.915 (+/-0.028) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.915 (+/-0.028) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.915 (+/-0.026) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.914 (+/-0.026) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.913 (+/-0.026) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.912 (+/-0.027) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.913 (+/-0.027) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.913 (+/-0.026) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.911 (+/-0.024) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.912 (+/-0.024) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.911 (+/-0.026) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.911 (+/-0.026) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.910 (+/-0.024) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.910 (+/-0.024) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.910 (+/-0.024) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.910 (+/-0.024) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.955 (+/-0.023) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.954 (+/-0.022) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.953 (+/-0.019) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.951 (+/-0.020) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.952 (+/-0.020) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.952 (+/-0.020) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.949 (+/-0.021) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.948 (+/-0.021) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.948 (+/-0.020) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.948 (+/-0.020) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.947 (+/-0.022) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.946 (+/-0.021) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.944 (+/-0.018) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.944 (+/-0.018) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.944 (+/-0.020) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.943 (+/-0.020) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.940 (+/-0.019) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.939 (+/-0.020) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.939 (+/-0.020) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.940 (+/-0.018) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.974 (+/-0.020) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.972 (+/-0.020) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.969 (+/-0.021) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.967 (+/-0.019) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.967 (+/-0.020) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.968 (+/-0.017) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.965 (+/-0.020) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.964 (+/-0.018) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.963 (+/-0.017) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.963 (+/-0.019) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.963 (+/-0.017) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.960 (+/-0.018) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.957 (+/-0.017) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.957 (+/-0.017) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.958 (+/-0.015) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.956 (+/-0.017) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.953 (+/-0.014) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.953 (+/-0.015) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.953 (+/-0.016) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.953 (+/-0.015) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 20}
# ____________________________________________ END GRID SEARCH ____________________________________________

# %%
results
# Out:
# {'f1_macro': {'criterion': 'entropy',
#   'max_depth': 10,
#   'min_samples_leaf': 3,
#   'min_samples_split': 5}}

# %%
clf = DecisionTreeClassifier(criterion = 'entropy', max_depth = 10, min_samples_leaf = 3, min_samples_split = 5, random_state=42)
clf.fit(X_res, y_res)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# Accuracy 0.8057142857142857
# F1-score [0.8913738  0.08108108]
#               precision    recall  f1-score   support
#
#            0       0.96      0.83      0.89       336
#            1       0.05      0.21      0.08        14
#
#     accuracy                           0.81       350
#    macro avg       0.51      0.52      0.49       350
# weighted avg       0.93      0.81      0.86       350

# %%
check_params = {'n_neighbors': [1, 5, 10, 15, 20], "weights":["distance", "uniform"], 'metric' :['minkowski', 'manhattan', 'euclidean']}

clf=KNeighborsClassifier()
          
results = customGridSearch(X_res, y_res, clf, check_params, "f1_macro")
# Out:
# ____________________________________________ START GRID SEARCH ____________________________________________
# ------- Score = f1_macro-------
#
# > Fold = RepeatedStratifiedKFold(n_repeats=10, n_splits=5, random_state=None)
#
# > Best Parameter set:
#
# {'metric': 'manhattan', 'n_neighbors': 1, 'weights': 'distance'}
#
# > Grid scores:
#
# ...........RESULTS FOR TRAINING.........
# ........................................
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 1, 'weights': 'distance'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 1, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 5, 'weights': 'distance'}
# 0.931 (+/-0.008) for {'metric': 'minkowski', 'n_neighbors': 5, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 10, 'weights': 'distance'}
# 0.899 (+/-0.009) for {'metric': 'minkowski', 'n_neighbors': 10, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 15, 'weights': 'distance'}
# 0.842 (+/-0.013) for {'metric': 'minkowski', 'n_neighbors': 15, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 20, 'weights': 'distance'}
# 0.828 (+/-0.012) for {'metric': 'minkowski', 'n_neighbors': 20, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 1, 'weights': 'distance'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 1, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'distance'}
# 0.946 (+/-0.006) for {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 10, 'weights': 'distance'}
# 0.922 (+/-0.007) for {'metric': 'manhattan', 'n_neighbors': 10, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 15, 'weights': 'distance'}
# 0.885 (+/-0.009) for {'metric': 'manhattan', 'n_neighbors': 15, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 20, 'weights': 'distance'}
# 0.874 (+/-0.012) for {'metric': 'manhattan', 'n_neighbors': 20, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 1, 'weights': 'distance'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 1, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 5, 'weights': 'distance'}
# 0.931 (+/-0.008) for {'metric': 'euclidean', 'n_neighbors': 5, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 10, 'weights': 'distance'}
# 0.899 (+/-0.009) for {'metric': 'euclidean', 'n_neighbors': 10, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 15, 'weights': 'distance'}
# 0.842 (+/-0.013) for {'metric': 'euclidean', 'n_neighbors': 15, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 20, 'weights': 'distance'}
# 0.828 (+/-0.012) for {'metric': 'euclidean', 'n_neighbors': 20, 'weights': 'uniform'}
# ____________________________________________ END GRID SEARCH ____________________________________________

# %%
#KNN
clf = KNeighborsClassifier(n_neighbors=5, weights='distance', metric='manhattan')
clf.fit(X_res, y_res)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# Accuracy 0.7114285714285714
# F1-score [0.82852292 0.09009009]
#               precision    recall  f1-score   support
#
#            0       0.96      0.73      0.83       336
#            1       0.05      0.36      0.09        14
#
#     accuracy                           0.71       350
#    macro avg       0.51      0.54      0.46       350
# weighted avg       0.93      0.71      0.80       350

# %% [markdown]
# ADASYN

# %%
ada = ADASYN(random_state=42)
X_res, y_res = ada.fit_resample(X_train, y_train['emotional_intensity'])
print('Resampled dataset shape %s' % Counter(y_res))
# Out:
# Resampled dataset shape Counter({1: 985, 0: 984})

# %%
pca = PCA(n_components=2)
pca.fit(X_train)
X_pca = pca.transform(X_res)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_res, cmap=plt.cm.prism, edgecolor='k', alpha=0.7)
plt.show()

# %%
check_params ={"criterion":["gini", "entropy"],
         "max_depth":[4, 6, 8, 10],
         "min_samples_split": [5, 10, 15, 20],
         "min_samples_leaf": [3, 5, 7, 9, 11]}

dt=DecisionTreeClassifier()
          
results = customGridSearch(X_res, y_res, dt, check_params, "f1_macro")
# Out:
# ____________________________________________ START GRID SEARCH ____________________________________________
# ------- Score = f1_macro-------
#
# > Fold = RepeatedStratifiedKFold(n_repeats=10, n_splits=5, random_state=None)
#
# > Best Parameter set:
#
# {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 5}
#
# > Grid scores:
#
# ...........RESULTS FOR TRAINING.........
# ........................................
# 0.867 (+/-0.022) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.866 (+/-0.022) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.866 (+/-0.023) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.866 (+/-0.023) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.866 (+/-0.023) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.865 (+/-0.023) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.865 (+/-0.023) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.865 (+/-0.023) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.865 (+/-0.022) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.865 (+/-0.022) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.865 (+/-0.022) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.864 (+/-0.022) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.863 (+/-0.021) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.863 (+/-0.021) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.863 (+/-0.021) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.863 (+/-0.021) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.862 (+/-0.021) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.862 (+/-0.021) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.862 (+/-0.021) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.862 (+/-0.021) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.932 (+/-0.032) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.931 (+/-0.032) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.930 (+/-0.033) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.929 (+/-0.032) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.928 (+/-0.031) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.928 (+/-0.031) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.927 (+/-0.031) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.927 (+/-0.031) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.925 (+/-0.030) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.925 (+/-0.030) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.924 (+/-0.030) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.924 (+/-0.030) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.921 (+/-0.027) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.921 (+/-0.027) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.921 (+/-0.027) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.921 (+/-0.027) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.918 (+/-0.026) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.918 (+/-0.026) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.918 (+/-0.026) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.918 (+/-0.026) for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.959 (+/-0.030) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.958 (+/-0.030) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.956 (+/-0.029) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.954 (+/-0.028) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.954 (+/-0.029) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.954 (+/-0.029) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.952 (+/-0.028) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.951 (+/-0.028) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.948 (+/-0.027) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.948 (+/-0.027) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.948 (+/-0.027) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.947 (+/-0.026) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.942 (+/-0.025) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.942 (+/-0.025) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.942 (+/-0.025) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.942 (+/-0.026) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.937 (+/-0.024) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.937 (+/-0.024) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.937 (+/-0.024) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.937 (+/-0.024) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.972 (+/-0.019) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.970 (+/-0.019) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.968 (+/-0.019) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.965 (+/-0.020) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.965 (+/-0.019) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.965 (+/-0.019) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.963 (+/-0.020) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.961 (+/-0.020) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.958 (+/-0.018) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.958 (+/-0.017) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.957 (+/-0.018) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.957 (+/-0.017) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.951 (+/-0.016) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.951 (+/-0.016) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.951 (+/-0.016) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.950 (+/-0.016) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.945 (+/-0.014) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.945 (+/-0.014) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.945 (+/-0.014) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.945 (+/-0.014) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.848 (+/-0.039) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.847 (+/-0.039) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.847 (+/-0.040) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.847 (+/-0.038) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.847 (+/-0.039) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.847 (+/-0.039) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.847 (+/-0.038) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.847 (+/-0.038) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.847 (+/-0.037) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.847 (+/-0.037) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.846 (+/-0.038) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.846 (+/-0.038) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.846 (+/-0.036) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.845 (+/-0.037) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.845 (+/-0.037) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.845 (+/-0.037) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.844 (+/-0.037) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.844 (+/-0.037) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.844 (+/-0.037) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.844 (+/-0.037) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.926 (+/-0.033) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.924 (+/-0.035) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.923 (+/-0.036) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.923 (+/-0.032) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.923 (+/-0.034) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.924 (+/-0.033) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.922 (+/-0.034) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.922 (+/-0.031) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.920 (+/-0.032) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.921 (+/-0.030) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.920 (+/-0.032) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.920 (+/-0.030) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.918 (+/-0.029) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.918 (+/-0.030) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.918 (+/-0.030) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.918 (+/-0.029) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.915 (+/-0.026) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.915 (+/-0.026) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.915 (+/-0.026) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.915 (+/-0.026) for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.963 (+/-0.025) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.962 (+/-0.025) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.960 (+/-0.024) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.958 (+/-0.024) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.959 (+/-0.025) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.959 (+/-0.025) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.957 (+/-0.025) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.955 (+/-0.024) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.954 (+/-0.023) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.954 (+/-0.023) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.954 (+/-0.023) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.952 (+/-0.022) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.949 (+/-0.020) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.949 (+/-0.020) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.949 (+/-0.020) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.948 (+/-0.020) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.944 (+/-0.018) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.944 (+/-0.018) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.944 (+/-0.018) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.944 (+/-0.018) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 11, 'min_samples_split': 20}
# 0.979 (+/-0.015) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.978 (+/-0.015) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.975 (+/-0.014) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 15}
# 0.972 (+/-0.015) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 20}
# 0.973 (+/-0.015) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.973 (+/-0.014) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.971 (+/-0.014) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.968 (+/-0.014) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.967 (+/-0.013) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 5}
# 0.967 (+/-0.014) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.966 (+/-0.013) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 15}
# 0.964 (+/-0.012) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 20}
# 0.961 (+/-0.011) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.961 (+/-0.011) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.961 (+/-0.011) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.960 (+/-0.011) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 20}
# 0.954 (+/-0.010) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.954 (+/-0.010) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 10}
# 0.954 (+/-0.011) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 15}
# 0.954 (+/-0.011) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 20}
# ____________________________________________ END GRID SEARCH ____________________________________________

# %%
results
# Out:
# {'f1_macro': {'criterion': 'entropy',
#   'max_depth': 10,
#   'min_samples_leaf': 3,
#   'min_samples_split': 5}}

# %%
clf = DecisionTreeClassifier(criterion = 'entropy', max_depth = 10, min_samples_leaf = 3, min_samples_split = 5, random_state=42)
clf .fit(X_res, y_res)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# Accuracy 0.82
# F1-score [0.89952153 0.1369863 ]
#               precision    recall  f1-score   support
#
#            0       0.97      0.84      0.90       336
#            1       0.08      0.36      0.14        14
#
#     accuracy                           0.82       350
#    macro avg       0.53      0.60      0.52       350
# weighted avg       0.93      0.82      0.87       350

# %%
check_params = {'n_neighbors': [1, 5, 10, 15, 20], "weights":["distance", "uniform"], 'metric' :['minkowski', 'manhattan', 'euclidean']}

clf=KNeighborsClassifier()
          
results = customGridSearch(X_res, y_res, clf, check_params, "f1_macro")
# Out:
# ____________________________________________ START GRID SEARCH ____________________________________________
# ------- Score = f1_macro-------
#
# > Fold = RepeatedStratifiedKFold(n_repeats=10, n_splits=5, random_state=None)
#
# > Best Parameter set:
#
# {'metric': 'manhattan', 'n_neighbors': 1, 'weights': 'distance'}
#
# > Grid scores:
#
# ...........RESULTS FOR TRAINING.........
# ........................................
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 1, 'weights': 'distance'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 1, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 5, 'weights': 'distance'}
# 0.929 (+/-0.009) for {'metric': 'minkowski', 'n_neighbors': 5, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 10, 'weights': 'distance'}
# 0.900 (+/-0.010) for {'metric': 'minkowski', 'n_neighbors': 10, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 15, 'weights': 'distance'}
# 0.842 (+/-0.012) for {'metric': 'minkowski', 'n_neighbors': 15, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'minkowski', 'n_neighbors': 20, 'weights': 'distance'}
# 0.830 (+/-0.011) for {'metric': 'minkowski', 'n_neighbors': 20, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 1, 'weights': 'distance'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 1, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'distance'}
# 0.945 (+/-0.008) for {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 10, 'weights': 'distance'}
# 0.922 (+/-0.008) for {'metric': 'manhattan', 'n_neighbors': 10, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 15, 'weights': 'distance'}
# 0.883 (+/-0.009) for {'metric': 'manhattan', 'n_neighbors': 15, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'manhattan', 'n_neighbors': 20, 'weights': 'distance'}
# 0.871 (+/-0.010) for {'metric': 'manhattan', 'n_neighbors': 20, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 1, 'weights': 'distance'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 1, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 5, 'weights': 'distance'}
# 0.929 (+/-0.009) for {'metric': 'euclidean', 'n_neighbors': 5, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 10, 'weights': 'distance'}
# 0.900 (+/-0.010) for {'metric': 'euclidean', 'n_neighbors': 10, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 15, 'weights': 'distance'}
# 0.842 (+/-0.012) for {'metric': 'euclidean', 'n_neighbors': 15, 'weights': 'uniform'}
# 1.000 (+/-0.000) for {'metric': 'euclidean', 'n_neighbors': 20, 'weights': 'distance'}
# 0.830 (+/-0.011) for {'metric': 'euclidean', 'n_neighbors': 20, 'weights': 'uniform'}
# ____________________________________________ END GRID SEARCH ____________________________________________

# %%
#KNN
clf = KNeighborsClassifier(n_neighbors=1, weights='distance', metric='manhattan')
clf.fit(X_res, y_res)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# Accuracy 0.7885714285714286
# F1-score [0.88141026 0.02631579]
#               precision    recall  f1-score   support
#
#            0       0.95      0.82      0.88       336
#            1       0.02      0.07      0.03        14
#
#     accuracy                           0.79       350
#    macro avg       0.49      0.44      0.45       350
# weighted avg       0.92      0.79      0.85       350

# %% [markdown]
# Balancing at the Algorithm Level
#
# Class Weight - Decision Tree

# %%
clf = DecisionTreeClassifier(min_samples_leaf=5, 
                             class_weight={0: 1, 1: 4}, random_state=42)
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# Accuracy 0.9485714285714286
# F1-score [0.97313433 0.4       ]
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97       336
#            1       0.38      0.43      0.40        14
#
#     accuracy                           0.95       350
#    macro avg       0.68      0.70      0.69       350
# weighted avg       0.95      0.95      0.95       350
